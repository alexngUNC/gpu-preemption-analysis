# %% [markdown]
# # Register and Thread State on Ada

# %%
from analyzer_functions import get_oh_dir, multi_boxplot
ohs = get_oh_dir('data/l2spin')
multi_boxplot(ohs, "Context Switch Overhead of Thread State", 'Register/Thread Configuration', ymin=50, ymax=90, tick_step=2)

# %% [markdown]
# # One Thread Block

# %%
stepwise_ohs = get_oh_dir('data/stepwise', debug=False)

# %%
multi_boxplot(stepwise_ohs, 'Context Switch Overhead of Threads of One Block', 'Register/Thread Configuration', ymin=50, ymax=70, tick_step=2, whiskers=1.5)

# %% [markdown]
# # SM Partitioning

# %%
tpc_ohs = get_oh_dir('data/sm')

# %%
multi_boxplot(tpc_ohs, 'Context Switch Overhead of SMs', 'Register/Thread Configuration', ymin=50, ymax=90, tick_step=2)
