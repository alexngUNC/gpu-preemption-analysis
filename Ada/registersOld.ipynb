# %%
from analyzer_functions import *

# %%
regs255_path = 'data/registers/ada-reg-255.csv'
regs10_path = 'data/registers/ada-reg-10.csv'
regs255_ivls = read_ivls(regs255_path, single=True)
regs10_ivls = read_ivls(regs10_path, single=True)
spin_path = 'data/ada-spin-100k.csv'
spin_ivls = read_ivls(spin_path, single=True)

# %%
N = 100000
plot_side_by_side(noSharedData=regs10_ivls, sharedData=regs255_ivls, NUM_SAMPLES=N, lowerBound=2200, upperBound=2300,
 				  firstLabel='10 registers per thread', secondLabel='255 registers per thread', medianLines=True)

# %%
N = 100000
plot_side_by_side(noSharedData=spin_ivls, sharedData=regs255_ivls, NUM_SAMPLES=N, lowerBound=2200, upperBound=2300,
 				  firstLabel='No registers', secondLabel='255 registers per thread', medianLines=True)
