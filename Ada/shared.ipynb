# %% [markdown]
# # Shared Memmory for RTX 6000 Ada

# %% [markdown]
# ## Carveout set to usage

# %%
from analyzer_functions import get_oh_dir, multi_boxplot
#ohs = get_oh_dir('data/shared/carveout1Block')
ohs = get_oh_dir('data/shared/carveout')
ohs = ohs.rename(columns={col: f"{((int(col) / 100) * 101376)/1024:.0f}" for col in ohs.columns})
fig_width = 3.5  # inches
fig_height = fig_width * 0.6  # adjust as neede
# multi_boxplot(ohs, "Context Switch Overhead of Shared Memory (RTX 6000 Ada)", "Shared Memory Per Thread Block (KB)", ymin=50, ymax=71, tick_step=2, minor_ticks=True, figsize=(fig_width, fig_height), save=None)
multi_boxplot(ohs, "Context Switch Overhead of Shared Memory (RTX 6000 Ada)", "Shared Memory Per Thread Block (KB)", ymin=50, ymax=71, tick_step=2, minor_ticks=True, figsize=(fig_width, fig_height), save='plots/shared/shared')
